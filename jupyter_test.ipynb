# %%
import pandas as pd
import sqlite3
df = pd.read_csv('Customer.csv')
df
# Out:
#      Age  Gender Payment Method Future Customer
# 0     64    male    credit card             yes
# 1     35    male         cheque             yes
# 2     25  female    credit card             yes
# 3     39  female    credit card              no
# 4     39    male    credit card             yes
# ..   ...     ...            ...             ...
# 995   29  female    credit card             yes
# 996   84    male    credit card              no
# 997   20    male    credit card             yes
# 998   19    male    credit card             yes
# 999   24  female    credit card             yes
#
# [1000 rows x 4 columns]

# %%
df.iloc[665]
# Out:
# Age                         48
# Gender                  female
# Payment Method     credit card
# Future Customer             no
# Name: 665, dtype: object

# %%
df[(df['Gender']=='female')&(df['Payment Method']=='credit card')]['Age'].mean()
# Out:
# 43.26262626262626

# %%
df.tail(10)[['Age','Payment Method']]
# Out:
#      Age Payment Method
# 990   50           cash
# 991   28    credit card
# 992   82           cash
# 993   64    credit card
# 994   19    credit card
# 995   29    credit card
# 996   84    credit card
# 997   20    credit card
# 998   19    credit card
# 999   24    credit card

# %%
df.sort_values(by='Age')[['Age','Payment Method']].head(10)
# Out:
#      Age Payment Method
# 539   17    credit card
# 592   17    credit card
# 946   17    credit card
# 192   17    credit card
# 663   17    credit card
# 211   17         cheque
# 561   17    credit card
# 316   17           cash
# 181   17           cash
# 22    17    credit card

# %%
df.sort_values(by="Age", ascending=True)[['Age','Payment Method']].head(10)
# Out:
#      Age Payment Method
# 181   17           cash
# 141   17    credit card
# 139   17    credit card
# 843   17    credit card
# 777   17    credit card
# 770   17    credit card
# 539   17    credit card
# 753   17    credit card
# 749   17    credit card
# 748   17    credit card

# %%
df.groupby(['Age','Payment Method']).agg({'Age':['min']})
# Out:
#                    Age
#                    min
# Age Payment Method
# 17  cash            17
#     cheque          17
#     credit card     17
# 18  cash            18
#     cheque          18
# ...                 ..
# 89  credit card     89
# 90  cash            90
#     credit card     90
# 91  cheque          91
#     credit card     91
#
# [188 rows x 1 columns]

# %%
df = df[df['Payment Method']!='cheque']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 932 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              932 non-null    int64
#  1   Gender           932 non-null    object
#  2   Payment Method   932 non-null    object
#  3   Future Customer  932 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 36.4+ KB

# %%
df2 =pd.read_csv('campaign_data.csv')

# %%
df2.head()
# Out:
#    campaignid  delivered  opened  clicked  campaign_sent_period  \
# 0           1         70      28        0                     1
# 1           2     593202  103976     2071                     1
# 2           3      24693    2532       43                     1
# 3           4       3377     971       22                     0
# 4           5     329913  101421     1680                     0
#
#    avg_days_since_last_purchased  percent_discount_offered  orders
# 0                             58                       0.0       0
# 1                             25                       0.0     117
# 2                             15                       0.0       5
# 3                              2                       0.0       2
# 4                              4                       0.5     166

# %%
# df2 = df2[(df2['opened']<=df2['delivered'])]

# %%
df2
# Out:
#         campaignid  delivered  opened  clicked  campaign_sent_period  \
# 0                1         70      28        0                     1
# 1                2     593202  103976     2071                     1
# 2                3      24693    2532       43                     1
# 3                4       3377     971       22                     0
# 4                5     329913  101421     1680                     0
# ...            ...        ...     ...      ...                   ...
# 499994      499995      53739    5136       98                     0
# 499995      499996      40098    5991      103                     2
# 499996      499997       4590     694       12                     1
# 499997      499998      24500    3734      182                     0
# 499998      499999      12064     932       28                     1
#
#         avg_days_since_last_purchased  percent_discount_offered  orders
# ...

# %%
df3.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12524/2918666566.py in <module>
# ----> 1 df3.index
#
# NameError: name 'df3' is not defined

# %%
df2.drop(df3.index)
# Out:
#         campaignid  delivered  opened  clicked  campaign_sent_period  \
# 0                1         70      28        0                     1
# 1                2     593202  103976     2071                     1
# 2                3      24693    2532       43                     1
# 3                4       3377     971       22                     0
# 4                5     329913  101421     1680                     0
# ...            ...        ...     ...      ...                   ...
# 499994      499995      53739    5136       98                     0
# 499995      499996      40098    5991      103                     2
# 499996      499997       4590     694       12                     1
# 499997      499998      24500    3734      182                     0
# 499998      499999      12064     932       28                     1
#
#         avg_days_since_last_purchased  percent_discount_offered  orders
# ...

# %%
with open('lord_of_the_ring.txt', encoding='cp1252') as f:
    word_count =0
    for line in f:
        for words in line.split():
            word_count +=1
word_count
# Out:
# 187960

# %%
pokemon_db = sqlite3.connect('./pokemon.db')
cursor = pokemon_db.cursor()
cursor.execute('select * from pokemon_meta')
for row in cursor.fetchall():
    print(row)
# Out:
# (1, 'Bulbasaur', 'grass', 'poison', 6.9, 0.7, 0.9, 32, 'Bulbsaur Candy', 5, 'Ivysaur', 25)
# (2, 'Ivysaur', 'grass', 'poison', 13.0, 1.0, 0.7, 40, 'Bulbsaur Candy', 0, 'Venusaur', 100)
# (3, 'Venusaur', 'grass', 'poison', 100.0, 2.0, 0.3, 53, 'Bulbsaur Candy', 0, 'None', -1)
# (4, 'Charmander', 'fire', 'None', 8.5, 0.6, 0.9, 32, 'Charmander Candy', 5, 'Charmeleon', 25)
# (5, 'Charmeleon', 'fire', 'None', 19.0, 1.1, 0.7, 40, 'Charmander Candy', 0, 'Charizard', 100)
# (6, 'Charizard', 'fire', 'flying', 90.5, 1.7, 0.3, 53, 'Charmander Candy', 0, 'None', -1)
# (7, 'Squirtle', 'water', 'None', 9.0, 0.5, 0.9, 32, 'Squirtle Candy', 5, 'Wartortle', 25)
# (8, 'Wartortle', 'water', 'None', 22.5, 1.0, 0.8, 40, 'Squirtle Candy', 0, 'Blastoise', 100)
# (9, 'Blastoise', 'water', 'None', 85.5, 1.6, 0.3, 53, 'Squirtle Candy', 0, 'None', -1)
# (10, 'Caterpie', 'bug', 'None', 2.9, 0.3, 1.0, 20, 'Caterpie Candy', 2, 'Metapod', 12)
# ...

# %%
s='I have never taken an exam like this'
s[16:25]
# Out:
# 'en an exa'
